# %% [markdown]
# # Preliminaries
#
# The `pandas` library allows the user several data structures for different data manipulation tasks:
# 1. Data storage through its `Series` and `DataFrame` data structures.
# 2. Data filtering using multiple methods from the package.
# 3. Reading data from many different file formats such as `csv`, `txt`, `xlsx`, ...
#
# Below we provide a brief overview of the `pandas` functionalities needed for these exercises. The complete documentation can be found on the [`pandas` website](https://pandas.pydata.org/).
#
# ## Pandas data structures
#
# ### Series
# The Pandas Series data structure is similar to a one-dimensional array. It can store any type of data. The values are mutable but the size not.
#
# To create `Series`, we call the `pd.Series()` method and pass an array. A `Series` may also be created from a numpy array.

# %%
import pandas as pd
import numpy as np

first_series = pd.Series([1,10,100,1000])

print(first_series)

teams = np.array(['PSV','Ajax','Feyenoord','Twente'])
second_series = pd.Series(teams)

print('\n')
print(second_series)
# Out:
# 0       1
# 1      10
# 2     100
# 3    1000
# dtype: int64
#
#
# 0          PSV
# 1         Ajax
# 2    Feyenoord
# 3       Twente
# dtype: object

# %% [markdown]
# ### DataFrame
# One can think of a `DataFrame` as a table with rows and columns (2D structure). The columns can be of a different type (as opposed to `numpy` arrays) and the size of the `DataFrame` is mutable.
#
# To create `DataFrame`, we call the `pd.DataFrame()` method and we can create it from scratch or we can convert a numpy array or a list into a `DataFrame`.

# %%
# DataFrame from scratch
first_dataframe = pd.DataFrame({
    "Position": [1, 2, 3, 4],
    "Team": ['PSV','Ajax','Feyenoord','Twente'],
    "GF": [80, 75, 75, 70],
    "GA": [30, 25, 40, 60],
    "Points": [79, 78, 70, 66]
})

print("From scratch: \n {} \n".format(first_dataframe))

# DataFrme from a list
data = [[1, 2, 3, 4], ['PSV','Ajax','Feyenoord','Twente'], 
        [80, 75, 75, 70], [30, 25, 40, 60], [79, 78, 70, 66]]
columns = ["Position", "Team", "GF", "GA", "Points"]

second_dataframe = pd.DataFrame(data, index=columns)

print("From list: \n {} \n".format(second_dataframe.T)) # the '.T' operator is explained later on

# DataFrame from numpy array
data = np.array([[1, 2, 3, 4], ['PSV','Ajax','Feyenoord','Twente'], 
                 [80, 75, 75, 70], [30, 25, 40, 60], [79, 78, 70, 66]])
columns = ["Position", "Team", "GF", "GA", "Points"]

third_dataframe = pd.DataFrame(data.T, columns=columns)

print("From numpy array: \n {} \n".format(third_dataframe))
# Out:
# From scratch:
#     Position       Team  GF  GA  Points
# 0         1        PSV  80  30      79
# 1         2       Ajax  75  25      78
# 2         3  Feyenoord  75  40      70
# 3         4     Twente  70  60      66
#
# From list:
#    Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66
#
# From numpy array:
#    Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66

# %% [markdown]
# ### DataFrame attributes
# This section gives a quick overview of some of the `pandas.DataFrame` attributes such as `T`, `index`, `columns`, `iloc`, `loc`, `shape` and `values`.

# %%
# transpose the index and columns
print(third_dataframe.T)
# Out:
#             0     1          2       3
# Position    1     2          3       4
# Team      PSV  Ajax  Feyenoord  Twente
# GF         80    75         75      70
# GA         30    25         40      60
# Points     79    78         70      66

# %%
# index makes reference to the row labels
print(third_dataframe.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# columns makes reference to the column labels
print(third_dataframe.columns)
# Out:
# Index(['Position', 'Team', 'GF', 'GA', 'Points'], dtype='object')

# %%
# iloc allows to access the index by integer-location (e.g. all team names, which are in the second columm)
print(third_dataframe.iloc[:,1])
# Out:
# 0          PSV
# 1         Ajax
# 2    Feyenoord
# 3       Twente
# Name: Team, dtype: object

# %%
# loc allows to access the index by label(s)-location (e.g. all team names, which are in the "Team" columm)
print(third_dataframe.loc[0, 'Team'])
# Out:
# PSV

# %%
# shape returns a tuple with the DataFrame dimension, similar to numpy
print(third_dataframe.shape)
# Out:
# (4, 5)

# %%
# values return a Numpy representation of the DataFrame data
print(third_dataframe.values)
# Out:
# [['1' 'PSV' '80' '30' '79']
#  ['2' 'Ajax' '75' '25' '78']
#  ['3' 'Feyenoord' '75' '40' '70']
#  ['4' 'Twente' '70' '60' '66']]

# %% [markdown]
# ### DataFrame methods
# This section gives a quick overview of some of the `pandas.DataFrame` methods such as `head`, `describe`, `concat`, `groupby`,`rename`, `filter`, `drop` and `isna`. To import data from CSV or MS Excel files, we can make use of `read_csv` and `read_excel`, respectively.

# %%
# print the first few rows in your dataset with head()
print(third_dataframe.head()) # In this case, it is not very useful because we don't have thousands of rows
# Out:
#   Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66

# %%
# get the summary statistics of the DataFrame with describe()
print(third_dataframe.describe())
# Out:
#        Position Team  GF  GA Points
# count         4    4   4   4      4
# unique        4    4   3   4      4
# top           2  PSV  75  25     79
# freq          1    1   2   1      1

# %%
# concatenate (join) DataFrame objects using concat()

# first, we will split the above DataFrame in two different ones
df_a = third_dataframe.loc[[0,1],:]
df_b = third_dataframe.loc[[2,3],:]

print(df_a)
print('\n')

print(df_b)
print('\n')

# now, we concatenate both datasets
df = pd.concat([df_a, df_b])

print(df)
# Out:
#   Position  Team  GF  GA Points
# 0        1   PSV  80  30     79
# 1        2  Ajax  75  25     78
#
#
#   Position       Team  GF  GA Points
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66
#
#
#   Position       Team  GF  GA Points
# 0        1        PSV  80  30     79
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70
# 3        4     Twente  70  60     66

# %%
# group the data by certain variable via groupby()
# here, we have grouped the data by goals for, which in this case is 75

group = df.groupby('GF')

print(group.get_group('75'))
# Out:
#   Position       Team  GF  GA Points
# 1        2       Ajax  75  25     78
# 2        3  Feyenoord  75  40     70

# %%
# rename() helps you change the column or index names
print(df.rename(columns={'Position':'Pos','Team':'Club'}))
# Out:
#   Pos       Club  GF  GA Points
# 0   1        PSV  80  30     79
# 1   2       Ajax  75  25     78
# 2   3  Feyenoord  75  40     70
# 3   4     Twente  70  60     66

# %%
# build a subset of rows or columns of your dataset according to labels via filter()
# here, items refer to the variable names: 'Team' and 'Points'; to select columns, we specify axis=1
print(df.filter(items=['Team', 'Points'], axis=1))
# Out:
#         Team Points
# 0        PSV     79
# 1       Ajax     78
# 2  Feyenoord     70
# 3     Twente     66

# %%
# dropping some labels
print(df.drop(columns=['GF', 'GA']))
# Out:
#   Position       Team Points
# 0        1        PSV     79
# 1        2       Ajax     78
# 2        3  Feyenoord     70
# 3        4     Twente     66

# %%
# search for NA (not available) entries in the DataFrame
print(df.isna()) # No NA values
print('\n')

# create a pandas Series with a NA value
# the Series as W (winnin matches)
tmp = pd.Series([np.NaN, 25, 24, 19],  name="W")

# concatenate the Series with the DataFrame
df = pd.concat([df,tmp], axis = 1)
print(df)
print('\n')

# again, check for NA entries
print(df.isna())
# Out:
#    Position   Team     GF     GA  Points
# 0     False  False  False  False   False
# 1     False  False  False  False   False
# 2     False  False  False  False   False
# 3     False  False  False  False   False
#
#
#   Position       Team  GF  GA Points     W
# 0        1        PSV  80  30     79   NaN
# 1        2       Ajax  75  25     78  25.0
# 2        3  Feyenoord  75  40     70  24.0
# 3        4     Twente  70  60     66  19.0
#
#
#    Position   Team     GF     GA  Points      W
# 0     False  False  False  False   False   True
# 1     False  False  False  False   False  False
# 2     False  False  False  False   False  False
# 3     False  False  False  False   False  False

# %% [markdown]
# ## Dataset
#
# For this week exercises we will use a dataset from the Genomics of Drug Sensitivity in Cancer (GDSC) project (https://www.cancerrxgene.org/). In this study (['Iorio et al., Cell, 2016']()), 265 compounds were tested on 1001 cancer cell lines for which different types of -omics data (RNA expression, DNA methylation, Copy Number Alteration, DNA sequencing) are available. This is a valuable resource to look for biomarkers of drugs sensitivity in order to try to understand why cancer patients responds very differently to cancer drugs and find ways to assign the optimal treatment to each patient.
#
# For this exercise we will use a subset of the data, focusing the response to the drug YM155 (Sepantronium bromide) on four cancer types, for a total of 148 cancer cell lines.
#
# | ID          | Cancer type                      |
# |-------------|----------------------------------|
# |   COAD/READ | Colorectal adenocarcinoma        |
# |   NB        | Neuroblastoma                    |
# |   KIRC      | Kidney renal clear cell carcinoma|
# |   BRCA      | Breast carcinoma                 |
#
# We will use the RNA expression data (RMA normalised). Only genes with high variability across cell lines (variance > 5, resulting in 238 genes) have been kept.
#
# Drugs have been tested at different concentration, measuring each time the viability of the cells. Drug sensitivity is measured using the natural log of the fitted IC50 metric, which is defined as the half maximal inhibitory concentration. A lower IC50 corresponds to a more sensitive cell line because a lower amount of drug is sufficient to have a strong response, while a higher IC50 corresponds to a more resistant cell line because more drug is needed for killing the cells.
#
# Based on the IC50 metric, cells can be classified as sensitive or resistant. The classification is done by computing the $z$-score across all cell lines in the GDSC for each drug, and considering as sensitive the ones with $z$-score < 0 and resistant the ones with $z$-score > 0.
#
# The dataset is originally provided as 3 files ([original source](https://www.sciencedirect.com/science/article/pii/S0092867416307462?via%3Dihub)) :
#
# `GDSC_RNA_expression.csv`: gene expression matrix with the cell lines in the rows (148) and the genes in the columns (238).
#
# `GDSC_drug_response.csv`: vector with the cell lines response to the drug YM155 in terms of log(IC50) and as classification in sensitive or resistant.
#
# `GDSC_metadata.csv`: metadata for the 148 cell lines including name, COSMIC ID and tumor type (using the classification from ['The Cancer Genome Atlas TCGA'](https://www.cancer.gov/about-nci/organization/ccg/research/structural-genomics/tcga))
#
# For convenience, we provide the data already curated.
#
# `RNA_expression_curated.csv`: [148 cell lines , 238 genes]
#
# `drug_response_curated.csv`: [148 cell lines , YM155 drug]
#
# The curated data cam be read as `pandas` `DataFrame`s in the following way:

# %%
import pandas as pd

gene_expression = pd.read_csv("./data/RNA_expression_curated.csv", sep=',', header=0, index_col=0)
drug_response = pd.read_csv("./data/drug_response_curated.csv", sep=',', header=0, index_col=0)

# %% [markdown]
# You can use the `DataFrame`s directly as inputs to the the `sklearn` models. The advantage over using `numpy` arrays is that the variable are annotated, i.e. each input and output has a name.

# %% [markdown]
# ## Tools
# The `scikit-learn` library provides the required tools for linear regression/classification and shrinkage, as well as for logistic regression.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Note that the notation used for the hyperparameters in the `scikit-learn` library is different from the one used in the lecture. More specifically, in the lecture $\alpha$ is the tunable parameter to select the compromise between Ridge and Lasso. Whereas, `scikit-learn` library refers to `alpha` as the tunable parameter $\lambda$. Please check the documentation for more details.

# %% [markdown]
# # Exercises
#
# ## Selection of the hyperparameter
#
# Implement cross-validation (using `sklearn.grid_search.GridSearchCV`) to select the `alpha` hyperparameter of `sklearn.linear_model.Lasso`.
#
#
# ## Feature selection
#
# Look at the features selected using the hyperparameter which corresponds to the minimum cross-validation error.
#
# <p><font color='#770a0a'>Is the partition in training and validation sets playing a role in the selection of the hyperparameter? How will this affect the selection of the relevant features?</font></p>
#
# <p><font color='#770a0a'>Should the value of the intercept also be shrunk to zero with Lasso and Ridge regression? Motivate your answer.</font></p>
#
#
# ## Bias-variance
#
# Show the effect of the regularization on the parameter estimates in terms of bias and variance. For this you can repeat the optimization 100 times using bootstrap and visualise the profile of the Lasso regression coefficient over a grid of the hyperparameter, optionally including the variability as error bars.
#
# <p><font color='#770a0a'>Based on the visual analysis of the plot, what are your observation on bias and variance in relation to model complexity? Motivate your answer.</font></p>
#
#
# ## Logistic regression
#
# <p><font color='#770a0a'>Write the expression of the objective function for the penalized logistic regression with $L_1$ and $L_2$ regularisation (as in Elastic net).</font></p>

# %% [markdown]
# # Answers
#
# ## Selection of the hyperparameter

# %% [markdown]
# ## Feature selection

# %% [markdown]
# ## Bias-variance

# %%
# !!!
# please note: running this cell takes approximately 1 hour.
# to run faster, decrease n_bootstrap to e.g. 20
# !!!


from sklearn.utils import resample
import matplotlib.pyplot as plt

# Prepare the target variable (drug response)
y = drug_response['YM155']

# Initialize parameters for Lasso regularization (alphas) and bootstrap iterations
n_bootstrap = 100 
alphas = np.logspace(-4, 1, 50)  # A grid of alpha (regularization strength) values
lasso_coeffs = np.zeros((n_bootstrap, len(alphas), gene_expression.shape[1]))  # To store coefficients

# Perform bootstrap and Lasso regression for each alpha
for i in range(n_bootstrap):
    # Bootstrap sampling
    X_resampled, y_resampled = resample(gene_expression, y, random_state=i)
    
    # Loop through each alpha value and fit the Lasso model
    for j, alpha in enumerate(alphas):
        lasso = Lasso(alpha=alpha, max_iter=10000)
        lasso.fit(X_resampled, y_resampled)
        lasso_coeffs[i, j, :] = lasso.coef_

# Calculate mean and standard deviation of the coefficients across bootstrap iterations
coeff_mean = np.mean(lasso_coeffs, axis=0)
coeff_std = np.std(lasso_coeffs, axis=0)

# Plot the Lasso coefficients over the grid of alpha values
plt.figure(figsize=(10, 6))
for gene_idx in range(gene_expression.shape[1]):
    plt.errorbar(alphas, coeff_mean[:, gene_idx], yerr=coeff_std[:, gene_idx], alpha=0.5)

plt.xlabel('alpha')
plt.ylabel('Lasso Coefficients')
plt.title('Effect of Regularization on Lasso Coefficients (Bias-Variance Profile)')
plt.tight_layout()
plt.show()

# Plot the Lasso coefficients over the grid of alpha values
plt.figure(figsize=(10, 6))
for gene_idx in range(gene_expression.shape[1]):
    plt.errorbar(np.log10(alphas), coeff_mean[:, gene_idx], yerr=coeff_std[:, gene_idx], alpha=0.5)

plt.xlabel('log10(alpha)')
plt.ylabel('Lasso Coefficients')
plt.title('Effect of Regularization on Lasso Coefficients (Bias-Variance Profile)')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12912717964465728, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14633426861969984, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19089112467347832, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23324077757279343, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20802213538134834, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24317797580954814, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2600449523461795, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.298796991148383, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27987915226052007, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3439335566360517, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30739117783052505, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3045112351835576, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2716255136961536, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32527801403969003, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1399149049409369, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12761911091623407, tolerance: 0.11417143479729729
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1280874002042925, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1375298270532654, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15303565292453783, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17221391606085812, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14788493687302712, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1762769177407365, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11516356259120385, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18125546647452712, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2911095624039471, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3291550867977214, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1845889818902603, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20271336146770588, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1655763635133522, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13189433474099413, tolerance: 0.10544104432432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09438629331865084, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11783609946810594, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14253867773730172, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16984735891289193, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1822065967154434, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19323082580263476, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16863201099227645, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21313034496451477, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23638903386171106, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20536717917133737, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23283672569736116, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3031370653353301, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.36681630119502556, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.408103626217779, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5348970621327791, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27376446705802887, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24718118949703127, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22267246487970715, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24826802818758442, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3370834709666368, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09835067981539103, tolerance: 0.08715052074324325
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12227456101926568, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15213983590453925, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17213307728515717, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17966715326745958, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18106844626076982, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23968675340087278, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1827614187516203, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30920763815626306, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2863207775415536, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3648864425480821, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4655123465648782, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.264902847681924, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1497254265971226, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16567435328983965, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16499228961185364, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1693642770853807, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12012944544996818, tolerance: 0.09605163972972974
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1202565473737817, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15863375601592342, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1864648262306743, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2238445660191237, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.262262710466955, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30144637810380964, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3377909534268976, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3485238304205605, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3664497868656636, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3886388668854961, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3080686258237223, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3748233710264544, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.40518694013465945, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3711538315337932, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.37613801069306396, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10304746710636165, tolerance: 0.09739672452702704
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16441342428086134, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18632925288791385, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22552369289771385, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23083148367066542, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25887651602748624, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30469541317477955, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.34719043171451053, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.44868049896747714, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.44713874835027395, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5063483673957372, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.503078771558924, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5573472765029355, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8360150040529386, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.149363694324872, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1774687795517176, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.887147128510874, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5572986891322769, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.48959987762515444, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16110616071804884, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2386922302917882, tolerance: 0.125079310472973
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13228102809045805, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15284761942484001, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1596672463208195, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18329438443790053, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22501566512992527, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25951383370120706, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26832185345826814, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32747535929530086, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31331806113403415, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33284532687354285, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17989843521394502, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2934859397565337, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25683790196363193, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3171660802460589, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14524225971334065, tolerance: 0.11261282777027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13844335991985798, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1499492793731967, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14464942873114864, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2617569527237117, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3677663466498137, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33591579796603904, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3818330695348283, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3365338784903581, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5833370041691054, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6535902801380101, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11251381715201805, tolerance: 0.1104251093918919
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1240558967723435, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1458303072544189, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1407919339515524, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.138080786361041, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15619401155356374, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1195353503225994, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15037902200533992, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14826904981153347, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15263926617151846, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23055757444173924, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20247340808292652, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1998060809242113, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11191386088063739, tolerance: 0.1101512127027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1597245739301994, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1932420589496366, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22447636688886044, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2595218315443552, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2903578898323711, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27432372364914653, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28003471825056586, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35888204045796573, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31739398884115405, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.37340460227083644, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.431781120435862, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.684342544225616, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5778799592735462, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.39766540067122824, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12053594785913527, tolerance: 0.10328259027027027
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12660974561765106, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14850829389456477, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1587917360416218, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19433950136114092, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17604727934689143, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1822896456823141, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2593633325599582, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2304262310755655, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26935332922166155, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17904542970546516, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18907061001450814, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14689045807840212, tolerance: 0.10831511324324322
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1723371493834076, tolerance: 0.10831511324324322
#   positive)
# ...
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26448712875044816, tolerance: 0.13526341756756757
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13276630520420793, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14914572853076352, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13453085499038023, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16874824130236749, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21556526144006952, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2752949471726535, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.29250114670239097, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31460136186110327, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3479998427310111, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3566196081568863, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4505098829935977, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.43678838608797466, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33632501388216357, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.513652185956853, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2684237856179026, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16633725770857347, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.140674547661366, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1825667692522948, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12702982905401194, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15735786068986668, tolerance: 0.12542148182432433
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1493594803592842, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16445104019771245, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19141904731894918, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2206898147560899, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2659922474058003, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3044382782982626, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2632417975171595, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35844556227676927, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3799943182380941, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.49024327267120393, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5480239469586564, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7195420736284059, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8223716892530364, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2606179290385688, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8432790192094607, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.46899747675647385, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2589624205494411, tolerance: 0.12458893027027028
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18651178882584848, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22868023311246635, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23237201579357317, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.300705555731804, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4236482383002369, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4733398041851584, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5060889843958961, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.609947863029398, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8104307948144137, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9008024756048625, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9998360032175265, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8885422303311742, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7484857888280506, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6659556154822424, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6286030400403273, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7254938879148322, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5280399169087384, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.303265330726037, tolerance: 0.12256683317567568
#   positive)
# c:\Users\20192673\.conda\envs\8dm50\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1346593934418232, tolerance: 0.12256683317567568
#   positive)

# %% [markdown]
# The plot shows the coefficient estimates, including error bars, of the Lasso coefficients. Since $\alpha$ is the regularization parameter, it influences the penalty for overfitting. When $\alpha$ is high, the penalty is stronger, causing the Lasso model to shrink more coefficients, sometimes even to zero during optimization. This results in a model with **high bias** (low complexity). The model becomes simpler, and there is a risk of **underfitting** due to the small number of parameters.
#
# On the other hand, when $\alpha$ is low, there is less penalty for complexity, so many coefficients remain large. This leads to **high variance** (high complexity), increasing the risk of **overfitting**.
#
# Therefore, it is important to tune $\alpha$ carefully to find the right balance between underfitting and overfitting. The plots above show that an $\alpha$ below approximately 0.7 leads to too many large coefficients, while an $\alpha$ above 4 results in nearly all coefficients being shrunk to zero. Somewhere in between, there is a sweet spot with the optimal $\alpha$.

# %% [markdown]
# ## Logistic regression
